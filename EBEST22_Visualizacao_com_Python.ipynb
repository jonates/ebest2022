# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Entendendo o contexto**

# %% [markdown]
# ### **O Objetivo da Aula**

# %% [markdown]
# Compreender a mortalidade no Brasil por meio de visualização de dados.

# %% [markdown]
# ### **O dataset**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Sistema de Informações sobre Mortalidade (SIM)**
#
# O Sistema de Informações sobre Mortalidade (SIM) foi criado pelo DATASUS para a obtenção regular de dados sobre mortalidade no país. A partir da criação do SIM foi possível a captação de dados sobre mortalidade, de forma abrangente, para subsidiar as diversas esferas de gestão na saúde pública. Com base nessas informações é possível realizar análises de situação, planejamento e avaliação das ações e programas na área.

# %% [markdown]
# https://basedosdados.org/dataset/br-ms-sim?bdm_table=dicionario

# %% [markdown]
# ## **Configurando ambiente e baixando dados da base dos dados**

# %%
# Instalando a biblioteca basedosdados
# !pip install basedosdados
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting basedosdados
#   Downloading basedosdados-1.6.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 2.7 MB/s
# Collecting loguru<0.7.0,>=0.6.0
#   Downloading loguru-0.6.0-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 5.3 MB/s
# Requirement already satisfied: ipykernel==5.3.4 in /usr/local/lib/python3.7/dist-packages (from basedosdados) (5.3.4)
# Collecting mkdocstrings<0.19.0,>=0.18.1
#   Downloading mkdocstrings-0.18.1-py3-none-any.whl (24 kB)
# Collecting google-cloud-storage==1.42.3
#   Downloading google_cloud_storage-1.42.3-py2.py3-none-any.whl (105 kB)
#      |████████████████████████████████| 105 kB 42.4 MB/s
# Collecting ckanapi==4.6
#   Downloading ckanapi-4.6.tar.gz (32 kB)
# Collecting jupyter<2.0.0,>=1.0.0
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Collecting google-cloud-bigquery==2.30.1
#   Downloading google_cloud_bigquery-2.30.1-py2.py3-none-any.whl (203 kB)
#      |████████████████████████████████| 203 kB 42.5 MB/s
# Collecting pandas-gbq<0.18.0,>=0.17.4
#   Downloading pandas_gbq-0.17.9-py2.py3-none-any.whl (25 kB)
# Collecting Jinja2==3.0.3
#   Downloading Jinja2-3.0.3-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 49.3 MB/s
# Collecting mkdocs-click<0.6.0,>=0.5.0
#   Downloading mkdocs_click-0.5.0-py3-none-any.whl (14 kB)
# Collecting pytest==6.0.2
#   Downloading pytest-6.0.2-py3-none-any.whl (270 kB)
#      |████████████████████████████████| 270 kB 51.7 MB/s
# Collecting mkdocs-material<9.0.0,>=8.2.7
#   Downloading mkdocs_material-8.5.7-py3-none-any.whl (7.5 MB)
#      |████████████████████████████████| 7.5 MB 29.7 MB/s
# Requirement already satisfied: toml<0.11.0,>=0.10.2 in /usr/local/lib/python3.7/dist-packages (from basedosdados) (0.10.2)
# Collecting pyarrow==6.0.0
#   Downloading pyarrow-6.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25.5 MB)
#      |████████████████████████████████| 25.5 MB 10.2 MB/s
# Collecting pandas==1.2.4
#   Downloading pandas-1.2.4-cp37-cp37m-manylinux1_x86_64.whl (9.9 MB)
#      |████████████████████████████████| 9.9 MB 26.8 MB/s
# Requirement already satisfied: importlib-metadata<5.0.0,>=4.11.3 in /usr/local/lib/python3.7/dist-packages (from basedosdados) (4.13.0)
# Collecting pyaml==20.4.0
#   Downloading pyaml-20.4.0-py2.py3-none-any.whl (17 kB)
# Collecting mkdocs<2.0.0,>=1.2.3
#   Downloading mkdocs-1.4.1-py3-none-any.whl (3.6 MB)
#      |████████████████████████████████| 3.6 MB 38.3 MB/s
# Collecting tomlkit==0.7.0
#   Downloading tomlkit-0.7.0-py2.py3-none-any.whl (32 kB)
# Collecting google-cloud-bigquery-storage==1.1.0
#   Downloading google_cloud_bigquery_storage-1.1.0-py2.py3-none-any.whl (135 kB)
#      |████████████████████████████████| 135 kB 25.8 MB/s
# Collecting click==8.0.3
#   Downloading click-8.0.3-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 2.0 MB/s
# Collecting pandavro<2.0.0,>=1.6.0
#   Downloading pandavro-1.7.1.tar.gz (8.1 kB)
# Collecting ruamel.yaml==0.17.10
#   Downloading ruamel.yaml-0.17.10-py3-none-any.whl (108 kB)
#      |████████████████████████████████| 108 kB 39.8 MB/s
# Collecting tqdm==4.50.2
#   Downloading tqdm-4.50.2-py2.py3-none-any.whl (70 kB)
#      |████████████████████████████████| 70 kB 6.6 MB/s
# Collecting black==20.8b1
#   Downloading black-20.8b1.tar.gz (1.1 MB)
#      |████████████████████████████████| 1.1 MB 37.5 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting pathspec<1,>=0.6
#   Downloading pathspec-0.10.1-py3-none-any.whl (27 kB)
# Requirement already satisfied: regex>=2020.1.8 in /usr/local/lib/python3.7/dist-packages (from black==20.8b1->basedosdados) (2022.6.2)
# Collecting mypy-extensions>=0.4.3
#   Downloading mypy_extensions-0.4.3-py2.py3-none-any.whl (4.5 kB)
# Collecting typed-ast>=1.4.0
#   Downloading typed_ast-1.5.4-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (843 kB)
#      |████████████████████████████████| 843 kB 44.6 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from black==20.8b1->basedosdados) (4.1.1)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.7/dist-packages (from black==20.8b1->basedosdados) (1.4.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from ckanapi==4.6->basedosdados) (57.4.0)
# Collecting docopt
#   Downloading docopt-0.6.2.tar.gz (25 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from ckanapi==4.6->basedosdados) (2.23.0)
# Requirement already satisfied: python-slugify>=1.0 in /usr/local/lib/python3.7/dist-packages (from ckanapi==4.6->basedosdados) (6.1.2)
# Requirement already satisfied: six<2.0,>=1.9 in /usr/local/lib/python3.7/dist-packages (from ckanapi==4.6->basedosdados) (1.15.0)
# Collecting google-cloud-core<3.0.0dev,>=1.4.1
#   Downloading google_cloud_core-2.3.2-py2.py3-none-any.whl (29 kB)
# Collecting google-resumable-media<3.0dev,>=0.6.0
#   Downloading google_resumable_media-2.4.0-py2.py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 5.1 MB/s
# Requirement already satisfied: grpcio<2.0dev,>=1.38.1 in /usr/local/lib/python3.7/dist-packages (from google-cloud-bigquery==2.30.1->basedosdados) (1.49.1)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in /usr/local/lib/python3.7/dist-packages (from google-cloud-bigquery==2.30.1->basedosdados) (2.8.2)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-bigquery==2.30.1->basedosdados) (3.17.3)
# Requirement already satisfied: google-api-core[grpc]<3.0.0dev,>=1.29.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-bigquery==2.30.1->basedosdados) (1.31.6)
# Collecting proto-plus>=1.10.0
#   Downloading proto_plus-1.22.1-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 3.7 MB/s
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-cloud-bigquery==2.30.1->basedosdados) (21.3)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage==1.42.3->basedosdados) (1.35.0)
# Requirement already satisfied: ipython>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel==5.3.4->basedosdados) (7.9.0)
# Requirement already satisfied: traitlets>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel==5.3.4->basedosdados) (5.1.1)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipykernel==5.3.4->basedosdados) (5.1.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel==5.3.4->basedosdados) (6.1.12)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.7/dist-packages (from Jinja2==3.0.3->basedosdados) (2.0.1)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.7/dist-packages (from pandas==1.2.4->basedosdados) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.2.4->basedosdados) (2022.4)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from pyaml==20.4.0->basedosdados) (6.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from pytest==6.0.2->basedosdados) (22.1.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest==6.0.2->basedosdados) (8.14.0)
# Collecting pluggy<1.0,>=0.12
#   Downloading pluggy-0.13.1-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: py>=1.8.2 in /usr/local/lib/python3.7/dist-packages (from pytest==6.0.2->basedosdados) (1.11.0)
# Collecting iniconfig
#   Downloading iniconfig-1.1.1-py2.py3-none-any.whl (5.0 kB)
# Collecting ruamel.yaml.clib>=0.1.2
#   Downloading ruamel.yaml.clib-0.2.7-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (500 kB)
#      |████████████████████████████████| 500 kB 32.4 MB/s
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.29.0->google-cloud-bigquery==2.30.1->basedosdados) (1.56.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage==1.42.3->basedosdados) (4.9)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage==1.42.3->basedosdados) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage==1.42.3->basedosdados) (0.2.8)
# Collecting google-crc32c<2.0dev,>=1.0
#   Downloading google_crc32c-1.5.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (32 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata<5.0.0,>=4.11.3->basedosdados) (3.9.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from ipython>=5.0.0->ipykernel==5.3.4->basedosdados) (2.0.10)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.1-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 50.5 MB/s
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=5.0.0->ipykernel==5.3.4->basedosdados) (2.6.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=5.0.0->ipykernel==5.3.4->basedosdados) (0.7.5)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=5.0.0->ipykernel==5.3.4->basedosdados) (4.4.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython>=5.0.0->ipykernel==5.3.4->basedosdados) (0.2.0)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=5.0.0->ipykernel==5.3.4->basedosdados) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.10->ipython>=5.0.0->ipykernel==5.3.4->basedosdados) (0.8.3)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.7/dist-packages (from jupyter<2.0.0,>=1.0.0->basedosdados) (7.7.1)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.7/dist-packages (from jupyter<2.0.0,>=1.0.0->basedosdados) (6.1.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from jupyter<2.0.0,>=1.0.0->basedosdados) (5.6.1)
# Requirement already satisfied: notebook in /usr/local/lib/python3.7/dist-packages (from jupyter<2.0.0,>=1.0.0->basedosdados) (5.5.0)
# Collecting qtconsole
#   Downloading qtconsole-5.3.2-py3-none-any.whl (120 kB)
#      |████████████████████████████████| 120 kB 56.8 MB/s
# Collecting pyyaml-env-tag>=0.1
#   Downloading pyyaml_env_tag-0.1-py3-none-any.whl (3.9 kB)
# Collecting watchdog>=2.0
#   Downloading watchdog-2.1.9-py3-none-manylinux2014_x86_64.whl (78 kB)
#      |████████████████████████████████| 78 kB 5.6 MB/s
# Collecting ghp-import>=1.0
#   Downloading ghp_import-2.1.0-py3-none-any.whl (11 kB)
# Collecting mergedeep>=1.3.4
#   Downloading mergedeep-1.3.4-py3-none-any.whl (6.4 kB)
# Collecting markdown<3.4,>=3.2.1
#   Downloading Markdown-3.3.7-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 6.8 MB/s
# Collecting mkdocs-material-extensions>=1.0.3
#   Downloading mkdocs_material_extensions-1.1-py3-none-any.whl (7.9 kB)
# Collecting requests
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.2 MB/s
# Collecting pygments
#   Downloading Pygments-2.13.0-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 46.8 MB/s
# Collecting pymdown-extensions>=9.4
#   Downloading pymdown_extensions-9.7-py3-none-any.whl (218 kB)
#      |████████████████████████████████| 218 kB 43.3 MB/s
# Collecting mkdocstrings-python-legacy>=0.2
#   Downloading mkdocstrings_python_legacy-0.2.3-py3-none-any.whl (26 kB)
# Collecting mkdocs-autorefs>=0.3.1
#   Downloading mkdocs_autorefs-0.4.1-py3-none-any.whl (9.8 kB)
# Collecting mkdocstrings-python-legacy>=0.2
#   Downloading mkdocstrings_python_legacy-0.2.2-py3-none-any.whl (25 kB)
# Collecting pytkdocs>=0.14
#   Downloading pytkdocs-0.16.1-py3-none-any.whl (37 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=14.3->google-cloud-bigquery==2.30.1->basedosdados) (3.0.9)
# Collecting db-dtypes<2.0.0,>=0.3.1
#   Downloading db_dtypes-1.0.4-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: pydata-google-auth in /usr/local/lib/python3.7/dist-packages (from pandas-gbq<0.18.0,>=0.17.4->basedosdados) (1.4.0)
# Requirement already satisfied: google-auth-oauthlib>=0.0.1 in /usr/local/lib/python3.7/dist-packages (from pandas-gbq<0.18.0,>=0.17.4->basedosdados) (0.4.6)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib>=0.0.1->pandas-gbq<0.18.0,>=0.17.4->basedosdados) (1.3.1)
# Collecting fastavro==1.5.1
#   Downloading fastavro-1.5.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 30.3 MB/s
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=5.0.0->ipykernel==5.3.4->basedosdados) (0.2.5)
# Collecting protobuf>=3.12.0
#   Downloading protobuf-3.20.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 35.3 MB/s
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-cloud-storage==1.42.3->basedosdados) (0.4.8)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify>=1.0->ckanapi==4.6->basedosdados) (1.3)
# Requirement already satisfied: astunparse>=1.6 in /usr/local/lib/python3.7/dist-packages (from pytkdocs>=0.14->mkdocstrings-python-legacy>=0.2->mkdocstrings<0.19.0,>=0.18.1->basedosdados) (1.6.3)
# Requirement already satisfied: cached-property>=1.5 in /usr/local/lib/python3.7/dist-packages (from pytkdocs>=0.14->mkdocstrings-python-legacy>=0.2->mkdocstrings<0.19.0,>=0.18.1->basedosdados) (1.5.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6->pytkdocs>=0.14->mkdocstrings-python-legacy>=0.2->mkdocstrings<0.19.0,>=0.18.1->basedosdados) (0.37.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->ckanapi==4.6->basedosdados) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->ckanapi==4.6->basedosdados) (1.24.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests->ckanapi==4.6->basedosdados) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->ckanapi==4.6->basedosdados) (2022.9.24)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.0.1->pandas-gbq<0.18.0,>=0.17.4->basedosdados) (3.2.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->basedosdados) (3.6.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->basedosdados) (3.0.3)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->basedosdados) (0.2.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.7/dist-packages (from notebook->jupyter<2.0.0,>=1.0.0->basedosdados) (5.7.0)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook->jupyter<2.0.0,>=1.0.0->basedosdados) (1.8.0)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook->jupyter<2.0.0,>=1.0.0->basedosdados) (0.13.3)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.7/dist-packages (from notebook->jupyter<2.0.0,>=1.0.0->basedosdados) (23.2.1)
# Requirement already satisfied: jupyter-core>=4.4.0 in /usr/local/lib/python3.7/dist-packages (from notebook->jupyter<2.0.0,>=1.0.0->basedosdados) (4.11.1)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.1->notebook->jupyter<2.0.0,>=1.0.0->basedosdados) (0.7.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->basedosdados) (0.8.4)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->basedosdados) (0.6.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->basedosdados) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->basedosdados) (1.5.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->basedosdados) (0.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->basedosdados) (5.0.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.7/dist-packages (from nbformat->notebook->jupyter<2.0.0,>=1.0.0->basedosdados) (4.3.3)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/dist-packages (from nbformat->notebook->jupyter<2.0.0,>=1.0.0->basedosdados) (2.16.2)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook->jupyter<2.0.0,>=1.0.0->basedosdados) (5.10.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook->jupyter<2.0.0,>=1.0.0->basedosdados) (0.18.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->jupyter<2.0.0,>=1.0.0->basedosdados) (0.5.1)
# Collecting qtpy>=2.0.1
#   Downloading QtPy-2.2.1-py3-none-any.whl (82 kB)
#      |████████████████████████████████| 82 kB 562 kB/s
# Building wheels for collected packages: black, ckanapi, pandavro, docopt
#   Building wheel for black (PEP 517) ... done
#   Created wheel for black: filename=black-20.8b1-py3-none-any.whl size=124195 sha256=1092defde52e4ef63ad225b4e08e428b02c170a05884e8abce6c96ff79baf16a
#   Stored in directory: /root/.cache/pip/wheels/c5/85/79/f3af8daaf8037c0bf14beb3b7a1511a39b6e6902ca2aaf494e
#   Building wheel for ckanapi (setup.py) ... done
#   Created wheel for ckanapi: filename=ckanapi-4.6-py3-none-any.whl size=40703 sha256=ff63f76c5c073cc453c25dd1f8b7ca65c5c047817b424822c2a176ca261fddcc
#   Stored in directory: /root/.cache/pip/wheels/0f/f5/46/360296ef0079076b23d9dbcff2e09ad295d91d4919bd47c016
#   Building wheel for pandavro (setup.py) ... done
#   Created wheel for pandavro: filename=pandavro-1.7.1-py3-none-any.whl size=5689 sha256=d5e360cdd08148ffe3a130573b5a09b14c32eba0e4678e52d7844905f7f54a5a
#   Stored in directory: /root/.cache/pip/wheels/cf/dc/a2/f6ecb1c372207d6d233229e9de27e95307411ebab75b19db64
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13723 sha256=e38432f02df44e25f5ec200f483e1f316737dc47bf257451c693fe16fcaaac6b
#   Stored in directory: /root/.cache/pip/wheels/72/b0/3f/1d95f96ff986c7dfffe46ce2be4062f38ebd04b506c77c81b9
# Successfully built black ckanapi pandavro docopt
# Installing collected packages: pygments, jedi, protobuf, Jinja2, requests, watchdog, pyyaml-env-tag, mergedeep, markdown, google-crc32c, ghp-import, click, qtpy, pytkdocs, pyarrow, proto-plus, pandas, mkdocs, google-resumable-media, google-cloud-core, typed-ast, ruamel.yaml.clib, qtconsole, pymdown-extensions, pluggy, pathspec, mypy-extensions, mkdocstrings-python-legacy, mkdocs-material-extensions, mkdocs-autorefs, iniconfig, google-cloud-bigquery-storage, google-cloud-bigquery, fastavro, docopt, db-dtypes, tqdm, tomlkit, ruamel.yaml, pytest, pyaml, pandavro, pandas-gbq, mkdocstrings, mkdocs-material, mkdocs-click, loguru, jupyter, google-cloud-storage, ckanapi, black, basedosdados
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.6.1
#     Uninstalling Pygments-2.6.1:
#       Successfully uninstalled Pygments-2.6.1
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.17.3
#     Uninstalling protobuf-3.17.3:
#       Successfully uninstalled protobuf-3.17.3
#   Attempting uninstall: Jinja2
#     Found existing installation: Jinja2 2.11.3
#     Uninstalling Jinja2-2.11.3:
#       Successfully uninstalled Jinja2-2.11.3
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: markdown
#     Found existing installation: Markdown 3.4.1
#     Uninstalling Markdown-3.4.1:
#       Successfully uninstalled Markdown-3.4.1
#   Attempting uninstall: click
#     Found existing installation: click 7.1.2
#     Uninstalling click-7.1.2:
#       Successfully uninstalled click-7.1.2
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 6.0.1
#     Uninstalling pyarrow-6.0.1:
#       Successfully uninstalled pyarrow-6.0.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.5
#     Uninstalling pandas-1.3.5:
#       Successfully uninstalled pandas-1.3.5
#   Attempting uninstall: google-resumable-media
#     Found existing installation: google-resumable-media 0.4.1
#     Uninstalling google-resumable-media-0.4.1:
#       Successfully uninstalled google-resumable-media-0.4.1
#   Attempting uninstall: google-cloud-core
#     Found existing installation: google-cloud-core 1.0.3
#     Uninstalling google-cloud-core-1.0.3:
#       Successfully uninstalled google-cloud-core-1.0.3
#   Attempting uninstall: pluggy
#     Found existing installation: pluggy 0.7.1
#     Uninstalling pluggy-0.7.1:
#       Successfully uninstalled pluggy-0.7.1
#   Attempting uninstall: google-cloud-bigquery-storage
#     Found existing installation: google-cloud-bigquery-storage 1.1.2
#     Uninstalling google-cloud-bigquery-storage-1.1.2:
#       Successfully uninstalled google-cloud-bigquery-storage-1.1.2
#   Attempting uninstall: google-cloud-bigquery
#     Found existing installation: google-cloud-bigquery 1.21.0
#     Uninstalling google-cloud-bigquery-1.21.0:
#       Successfully uninstalled google-cloud-bigquery-1.21.0
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.64.1
#     Uninstalling tqdm-4.64.1:
#       Successfully uninstalled tqdm-4.64.1
#   Attempting uninstall: pytest
#     Found existing installation: pytest 3.6.4
#     Uninstalling pytest-3.6.4:
#       Successfully uninstalled pytest-3.6.4
#   Attempting uninstall: pandas-gbq
#     Found existing installation: pandas-gbq 0.13.3
#     Uninstalling pandas-gbq-0.13.3:
#       Successfully uninstalled pandas-gbq-0.13.3
#   Attempting uninstall: google-cloud-storage
#     Found existing installation: google-cloud-storage 1.18.1
#     Uninstalling google-cloud-storage-1.18.1:
#       Successfully uninstalled google-cloud-storage-1.18.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.9.2 requires protobuf<3.20,>=3.9.2, but you have protobuf 3.20.3 which is incompatible.
# tensorboard 2.9.1 requires protobuf<3.20,>=3.9.2, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-translate 1.5.0 requires google-cloud-core<2.0dev,>=1.0.0, but you have google-cloud-core 2.3.2 which is incompatible.
# google-cloud-firestore 1.7.0 requires google-cloud-core<2.0dev,>=1.0.3, but you have google-cloud-core 2.3.2 which is incompatible.
# google-cloud-datastore 1.8.0 requires google-cloud-core<2.0dev,>=1.0.0, but you have google-cloud-core 2.3.2 which is incompatible.
# flask 1.1.4 requires click<8.0,>=5.1, but you have click 8.0.3 which is incompatible.
# flask 1.1.4 requires Jinja2<3.0,>=2.10.1, but you have jinja2 3.0.3 which is incompatible.
# Successfully installed Jinja2-3.0.3 basedosdados-1.6.8 black-20.8b1 ckanapi-4.6 click-8.0.3 db-dtypes-1.0.4 docopt-0.6.2 fastavro-1.5.1 ghp-import-2.1.0 google-cloud-bigquery-2.30.1 google-cloud-bigquery-storage-1.1.0 google-cloud-core-2.3.2 google-cloud-storage-1.42.3 google-crc32c-1.5.0 google-resumable-media-2.4.0 iniconfig-1.1.1 jedi-0.18.1 jupyter-1.0.0 loguru-0.6.0 markdown-3.3.7 mergedeep-1.3.4 mkdocs-1.4.1 mkdocs-autorefs-0.4.1 mkdocs-click-0.5.0 mkdocs-material-8.5.7 mkdocs-material-extensions-1.1 mkdocstrings-0.18.1 mkdocstrings-python-legacy-0.2.2 mypy-extensions-0.4.3 pandas-1.2.4 pandas-gbq-0.17.9 pandavro-1.7.1 pathspec-0.10.1 pluggy-0.13.1 proto-plus-1.22.1 protobuf-3.20.3 pyaml-20.4.0 pyarrow-6.0.0 pygments-2.13.0 pymdown-extensions-9.7 pytest-6.0.2 pytkdocs-0.16.1 pyyaml-env-tag-0.1 qtconsole-5.3.2 qtpy-2.2.1 requests-2.28.1 ruamel.yaml-0.17.10 ruamel.yaml.clib-0.2.7 tomlkit-0.7.0 tqdm-4.50.2 typed-ast-1.5.4 watchdog-2.1.9

# %%
# Carregando a biblioteca
import basedosdados as bd

# %%
# Listando os datasets disponíveis
bd.list_datasets()
# Out:
# dataset_id:
# 	br-cvm-oferta-publica-distribuicao
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-cvm-administradores-carteira
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-bd-indicadores
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	nl-ug-pwt
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-bd-diretorios-mundo
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-seeg-emissoes
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	mundo-kaggle-olimpiadas
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-ibge-censo-demografico
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-ibge-nomes-brasil
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-me-rais
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-poder360-pesquisas
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-fgv-igp
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-cgu-pessoal-executivo-federal
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-tse-eleicoes
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-me-cnpj
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-camara-atividade-legislativa
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-capes-bolsas
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-ibge-ipca15
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-ibge-ipca
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-cgu-ebt
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-bcb-sicor
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	world-fifa-women-world-cup
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-geobr-mapas
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-inep-saeb
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-inep-sinopse-estatistica-educacao-basica
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-mec-prouni
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-ibge-inpc
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-sp-saopaulo-dieese-icv
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-me-caged
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-me-socios
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-me-cno
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-sp-alesp
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-ms-atencao-basica
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	mundo-transfermarkt-competicoes
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-abrinq-oca
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-ibge-amc
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-mobilidados-indicadores
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-mapbiomas-estatisticas
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-mc-auxilio-emergencial
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-ibge-pib
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-imprensa-nacional-dou
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-ibge-censo-agropecuario
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-ibge-pnadc
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-ana-atlas-esgotos
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-ms-populacao
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-ibge-ipp
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-ms-imunizacoes
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-sp-gov-ssp
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-ms-cnes
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-anatel-banda-larga-fixa
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-mme-consumo-energia-eletrica
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-ba-feiradesantana-camara-leis
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-inep-censo-escolar
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-anp-precos-combustiveis
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-tpe-classificacao-saeb
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-me-siconfi
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-ibge-pnad
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-camara-dados-abertos
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-sp-seduc-inse
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-sp-seduc-idesp
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-sp-seduc-fluxo-escolar
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-rj-rio-de-janeiro-ipp-ips
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-ipea-acesso-oportunidades
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-inep-indicadores-educacionais
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-inep-ideb
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-ibge-ppm
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-ibge-pnad-covid
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-ibge-pam
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-denatran-frota
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-bd-diretorios-data-tempo
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-anvisa-medicamentos-industrializados
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-tse-filiacao-partidaria
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-inep-ana
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-bd-vizinhanca
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-isp-estatisticas-seguranca
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-mc-indicadores
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-ggb-relatorio-lgbtqi
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-ibge-cbo-2002
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-cgu-servidores-executivo-federal
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	mundo-transrespect-transphobia
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-inep-formacao-docente
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-inep-indicador-nivel-socioeconomico
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	mundo-onu-adh
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-ons-energia-armazenada
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-ms-vacinacao-covid19
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-ms-sinan
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-anatel-telefonia-movel
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-ana-reservatorios
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-sp-gov-orcamento
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-senado-cpipandemia
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-inmet-bdmep
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-me-comex-stat
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-ibge-populacao
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-ms-sim
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-mma-extincao
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-bd-diretorios-brasil
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	eu-fra-lgbt
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-me-pensionistas
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-inpe-prodes
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	sinopses-estatisticas-da-educacao-basica
# -----------------------------------------------------------------------------------------------

# %%
# Consultando as tabelas de um dataset
# Como exemplo vamos utilizar o dataset da PNAD
bd.list_dataset_tables(
    dataset_id='br_ms_sim', 
    with_description=True
)
# Out:
# table_id:
# 	dicionario
# description:
# 	Dicionário para a base do Sistema de Informações de Mortalidade (SIM).
#
# -----------------------------------------------------------------------------------------------
# table_id:
# 	microdados
# description:
# 	Microdados do Sistema de Informações sobre Mortalidade (SIM) do Ministério da Saúde.
#
# -----------------------------------------------------------------------------------------------
# table_id:
# 	municipio
# description:
# 	Número de óbitos agregados dos microdados do Sistema de Informações sobre Mortalidade
# do Ministério da Saúde ao nível município-ano.
#
# -----------------------------------------------------------------------------------------------
# table_id:
# 	municipio_causa
# description:
# 	Número de óbitos agregados dos microdados do Sistema de Informações sobre Mortalidade
# do Ministério da Saúde ao nível município-causa-ano.
#
# -----------------------------------------------------------------------------------------------
# table_id:
# 	municipio_causa_idade
# description:
# 	Número de óbitos agregados dos microdados do Sistema de Informações sobre Mortalidade
# do Ministério da Saúde ao nível município-causa-idade-ano.
#
# -----------------------------------------------------------------------------------------------
# table_id:
# 	municipio_causa_idade_sexo_raca
# description:
# 	Número de óbitos agregados dos microdados do Sistema de Informações sobre Mortalidade
# do Ministério da Saúde ao nível município-causa-idade-sexo-raca-ano.
#
# -----------------------------------------------------------------------------------------------

# %%
# Consultando as tabelas de um dataset
# Como exemplo vamos utilizar o dataset da PNAD
bd.get_table_columns(
    dataset_id = 'br_ms_sim', 
    table_id = 'municipio'
)
# Out:
# name:
# 	ano
# bigquery_type:
# 	int64
# description:
# 	Ano
# temporal_coverage:
# 	['(1)']
# covered_by_dictionary:
# 	no
# directory_column:
# 	{'dataset_id': 'br_bd_diretorios_data_tempo', 'table_id': 'ano', 'column_name':
#
# measurement_unit:
# 	year
# has_sensitive_data:
# 	no
# observations:
# 	None
# is_in_staging:
# 	True
# is_partition:
# 	True
# -----------------------------------------------------------------------------------------------
# name:
# 	sigla_uf
# bigquery_type:
# 	string
# description:
# 	Sigla da Unidade da Federação
# temporal_coverage:
# 	['(1)']
# covered_by_dictionary:
# 	no
# directory_column:
# 	{'dataset_id': 'br_bd_diretorios_brasil', 'table_id': 'uf', 'column_name': 'sigla'}
# measurement_unit:
# 	None
# has_sensitive_data:
# 	no
# observations:
# 	None
# is_in_staging:
# 	True
# is_partition:
# 	True
# -----------------------------------------------------------------------------------------------
# name:
# 	id_municipio
# bigquery_type:
# 	string
# description:
# 	ID Município - IBGE 7 Dígitos
# temporal_coverage:
# 	['(1)']
# covered_by_dictionary:
# 	no
# directory_column:
# 	{'dataset_id': 'br_bd_diretorios_brasil', 'table_id': 'municipio', 'column_name':
#
# measurement_unit:
# 	None
# has_sensitive_data:
# 	no
# observations:
# 	None
# is_in_staging:
# 	True
# is_partition:
# 	False
# -----------------------------------------------------------------------------------------------
# name:
# 	numero_obitos
# bigquery_type:
# 	int64
# description:
# 	Número de Óbitos
# temporal_coverage:
# 	['(1)']
# covered_by_dictionary:
# 	no
# directory_column:
# 	{'dataset_id': None, 'table_id': None, 'column_name': None}
# measurement_unit:
# 	person
# has_sensitive_data:
# 	no
# observations:
# 	None
# is_in_staging:
# 	True
# is_partition:
# 	False
# -----------------------------------------------------------------------------------------------

# %% [markdown]
# ⚠️⚠️ **Atenção!!** Perceba que conseguimos consultar a lista das bases de dados, consultar as tabelas de uma base de dados e, inclusive, consultar os atributos de uma tabela sem precisar carregar essas tabelas no ambiente. Ou seja, não utilizamos recursos de armazenamento e nem fizemos download de dados.

# %%
# 1) Acesse: https://console.cloud.google.com/projectselector2/home/dashboard
# 2) Clique em Create Project/Criar Projeto. Escolha um nome bacana para o projeto.
# 3) Clique em Create/Criar

# %%
# Baixando a tabela
df = bd.read_table(dataset_id='br_ms_sim',
table_id='municipio',
billing_project_id="saude-366505")
# Out:
# Downloading:   0%|          | 0/132868 [00:00<?, ?rows/s]
# Downloading: 100%|██████████| 132868/132868 [00:04<00:00, 31514.12rows/s]

# %%
# Espiando a estrutura do dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132868 entries, 0 to 132867
# Data columns (total 4 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   ano            132868 non-null  Int64
#  1   sigla_uf       132868 non-null  object
#  2   id_municipio   132868 non-null  object
#  3   numero_obitos  132868 non-null  Int64
# dtypes: Int64(2), object(2)
# memory usage: 4.3+ MB

# %%
# Espiando o dataframe
df.head(5)
# Out:
#     ano sigla_uf id_municipio  numero_obitos
# 0  1996       AC      1200000              4
# 1  1996       AC      1200013              9
# 2  1996       AC      1200054              8
# 3  1996       AC      1200104             46
# 4  1996       AC      1200138              3

# %%
# Permitir o Google Colab utilizar arquivos do Google Drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# Salvando o df no drive
df.to_csv(path_or_buf='/content/drive/MyDrive/Quantitativamente/EBEST2022/municipio.csv', sep=';',index=False)

# %%
# Baixando a tabela municipio_causa_idade_sexo_raca
df2 = bd.read_table(dataset_id='br_ms_sim',
table_id='municipio_causa_idade_sexo_raca',
billing_project_id="saude-366505")

# %%
# Salvando o df2 no drive
df2.to_csv(path_or_buf='/content/drive/MyDrive/Quantitativamente/EBEST2022/municipio_causa_idade_sexo_raca.csv', sep=';')

# %%
# Baixando a tabela microdados
df3 = bd.read_table(dataset_id='br_ms_sim',
table_id='microdados',
billing_project_id="saude-366505")
# Out:
# Downloading:  61%|██████    | 17025284/27902869 [2:41:02<1:48:13, 1675.15rows/s]

# %%
# Salvando o df no drive
df3.to_csv(path_or_buf='/content/drive/MyDrive/Quantitativamente/EBEST2022/microdados.csv', sep=';')

# %% [markdown]
# ## **Dados agregados por municipio**

# %%
import pandas as pd

# %%
# Permitir o Google Colab utilizar arquivos do Google Drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
#Lendo o csv salvo no drive
sim_mun = pd.read_csv(
    filepath_or_buffer='/content/drive/MyDrive/Quantitativamente/EBEST2022/municipio.csv', 
    sep=';'
)

# %%
# Espiando o dataframe
sim_mun.head(5)
# Out:
#     ano sigla_uf  id_municipio  numero_obitos
# 0  1996       AC       1200000              4
# 1  1996       AC       1200013              9
# 2  1996       AC       1200054              8
# 3  1996       AC       1200104             46
# 4  1996       AC       1200138              3

# %%
# Espiando a estrutura do dataframe
sim_mun.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132868 entries, 0 to 132867
# Data columns (total 4 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   ano            132868 non-null  int64
#  1   sigla_uf       132868 non-null  object
#  2   id_municipio   132868 non-null  int64
#  3   numero_obitos  132868 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 4.1+ MB

# %% [markdown]
# #### **Óbitos por ano no Brasil**

# %%
# Agregando obitos por ano no Brasil
obitos_por_ano = sim_mun\
  .filter(items=['ano','numero_obitos'])\
  .groupby('ano', as_index = True)\
  .sum()\
  .reset_index()

# Verificando o resultado do dataframe gerado
obitos_por_ano
# Out:
#      ano  numero_obitos
# 0   1996         908883
# 1   1997         903516
# 2   1998         931895
# 3   1999         938658
# 4   2000         946686
# 5   2001         961492
# 6   2002         982807
# 7   2003        1002340
# 8   2004        1024073
# 9   2005        1006827
# 10  2006        1028172
# 11  2007        1044114
# 12  2008        1072822
# 13  2009        1098388
# 14  2010        1132888
# 15  2011        1166351
# 16  2012        1177145
# 17  2013        1206476
# 18  2014        1223152
# 19  2015        1260774
# 20  2016        1306311
# 21  2017        1309729
# 22  2018        1313887
# 23  2019        1347263

# %%
# Gerando um gráfico de linhas simples
obitos_por_ano.plot.line(x = 'ano', y = 'numero_obitos');

# %%
# Elaborando gráfico de linhas mais elaborado
obitos_por_ano.plot.line(
    x = 'ano', 
    y = 'numero_obitos',
    color = 'green',
    marker='p',
    linestyle = '--',
    figsize=(20, 6),
    title = 'Óbitos por ano, Brasil, 1996-2019.',
    ylabel='Quantidade de óbitos',
    xlabel='Ano'
);

# %% [markdown]
# #### **Óbitos por UF em 2019**

# %%
# Agregando obitos por UF do Brasil em 2019
obitos_por_UF = sim_mun\
  .query('ano==2019')\
  .groupby('sigla_uf', as_index = True)\
  .agg({"numero_obitos": "sum"})\
  .reset_index()

# Verificando o resultado do dataframe gerado
obitos_por_UF
# Out:
#    sigla_uf  numero_obitos
# 0        AC           4076
# 1        AL          20286
# 2        AM          18321
# 3        AP           3524
# 4        BA          93058
# 5        CE          56575
# 6        DF          12804
# 7        ES          24406
# 8        GO          40931
# 9        MA          35085
# 10       MG         140892
# 11       MS          16813
# 12       MT          18337
# 13       PA          40486
# 14       PB          27340
# 15       PE          64041
# 16       PI          20500
# 17       PR          74459
# 18       RJ         143641
# 19       RN          21765
# 20       RO           8319
# 21       RR           2779
# 22       RS          89238
# 23       SC          42263
# 24       SE          13468
# 25       SP         305858
# 26       TO           7998

# %%
# Gerando um gráfico de barras com o método plot.bar do Pandas
obitos_por_UF.sort_values('numero_obitos', ascending=True)\
  .plot.barh(
    x='sigla_uf',
    y = 'numero_obitos', 
    color = 'darkorange',
    figsize=(10, 6),
    title = 'Óbitos por Unidade da Federação, Brasil, 2019.',
    ylabel='Quantidade de óbitos',
    xlabel='Unidade da Federação',
    legend = False,
    width = 0.8
);

# %%
# Importando as bibliotecas necessarias
import matplotlib.pyplot as plt

# %%
# Gerando um gráfico de barras com o método plot.bar do Pandas
graf_obitos_uf = obitos_por_UF.sort_values('numero_obitos', ascending=True)\
  .plot.barh(
    x='sigla_uf',
    y = 'numero_obitos', 
    color = 'darkgreen',
    figsize=(10, 8),
    title = 'Óbitos por Unidade da Federação, Brasil, 2019.',
    ylabel='Quantidade de óbitos',
    xlabel='Unidade da Federação',
    legend = False,
    width = 0.8
)
  
# Adicionando rótulo de valores
for i in graf_obitos_uf.patches:
    plt.text(
        y = i.get_y()+0.3, 
        x = i.get_width(),
        s = str(i.get_width()),
       fontsize = 6.5, 
       fontweight ='bold',
       color ='black'
    );

# %% [markdown]
# Se fosse um gráfico de colunas usaria get_height() no lugar de get_width() e get_x() em vez de get_y()

# %% [markdown]
# #### **Mapa dos Óbitos por UF em 2019**

# %% [markdown]
# ##### **1. Organização dos dados geoespaciais**

# %%
#Instalando o Geopandas
# !pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting geopandas
#   Downloading geopandas-0.10.2-py2.py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 5.3 MB/s
# Requirement already satisfied: shapely>=1.6 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.8.5.post1)
# Collecting pyproj>=2.2.0
#   Downloading pyproj-3.2.1-cp37-cp37m-manylinux2010_x86_64.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 36.9 MB/s
# Collecting fiona>=1.8
#   Downloading Fiona-1.8.22-cp37-cp37m-manylinux2014_x86_64.whl (16.7 MB)
#      |████████████████████████████████| 16.7 MB 528 kB/s
# Requirement already satisfied: pandas>=0.25.0 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.2.4)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (22.1.0)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (57.4.0)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (1.15.0)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (2022.9.24)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (8.0.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from click>=4.0->fiona>=1.8->geopandas) (4.13.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (2022.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (2.8.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (1.21.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->click>=4.0->fiona>=1.8->geopandas) (3.9.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->click>=4.0->fiona>=1.8->geopandas) (4.1.1)
# Installing collected packages: munch, cligj, click-plugins, pyproj, fiona, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.7.2 fiona-1.8.22 geopandas-0.10.2 munch-2.5.0 pyproj-3.2.1

# %%
# Importando bibliotecas necessárias
import geopandas as gpd
import json

# %%
# Pegando o geojson
url_geojson = 'https://raw.githubusercontent.com/jonates/opendata/master/arquivos_geoespaciais/unidades_da_federacao.json'
geo_uf = gpd.read_file(url_geojson)

# %%
# Espiando a estrutura do objeto
geo_uf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   NM_ESTADO  27 non-null     object
#  1   NM_REGIAO  27 non-null     object
#  2   CD_GEOCUF  27 non-null     object
#  3   geometry   27 non-null     geometry
# dtypes: geometry(1), object(3)
# memory usage: 992.0+ bytes

# %%
#Espiando o objeto geoespacial
geo_uf.head()
# Out:
#   NM_ESTADO NM_REGIAO CD_GEOCUF  \
# 0      ACRE     NORTE        12
# 1   ALAGOAS  NORDESTE        27
# 2     AMAPÁ     NORTE        16
# 3  AMAZONAS     NORTE        13
# 4     BAHIA  NORDESTE        29
#
#                                             geometry
# 0  POLYGON ((-66.81025 -9.81805, -66.62672 -9.898...
# 1  POLYGON ((-35.15253 -8.91384, -35.30432 -9.190...
# 2  POLYGON ((-50.09391 0.70209, -50.27176 0.68823...
# 3  POLYGON ((-63.37209 2.21186, -63.27635 2.15439...
# 4  POLYGON ((-38.23759 -9.32979, -38.23654 -9.331...

# %% [markdown]
# ##### **2. Organização do dataframe**

# %%
# Espiando o df com dados de óbitos por UF em 2019
obitos_por_UF.head(5)
# Out:
#   sigla_uf  numero_obitos CD_GEOCUF
# 0       AC           4076        12
# 1       AL          20286        27
# 2       AM          18321        13
# 3       AP           3524        16
# 4       BA          93058        29

# %%
# Inserindo o codigo da UF no dataset
obitos_por_UF['CD_GEOCUF'] = obitos_por_UF['sigla_uf']\
  .replace(
      ['RO','AC','AM','RR','PA','AP','TO','MA','PI','CE','RN','PB','PE','AL','SE','BA','MG','ES','RJ','SP','PR','SC','RS','MS','MT','GO','DF'],
      ['11','12','13','14','15','16','17','21','22','23','24','25','26','27','28','29','31','32','33','35','41','42','43','50','51','52','53']
  )

# Espiando a tabela
obitos_por_UF.head(5)
# Out:
#   sigla_uf  numero_obitos CD_GEOCUF
# 0       AC           4076        12
# 1       AL          20286        27
# 2       AM          18321        13
# 3       AP           3524        16
# 4       BA          93058        29

# %%
# Levando os dados para dentro do objeto geoespacial
geo_uf = geo_uf.merge(obitos_por_UF, on='CD_GEOCUF')

#Espiando resultado
geo_uf.head()
# Out:
#   NM_ESTADO NM_REGIAO CD_GEOCUF  \
# 0      ACRE     NORTE        12
# 1   ALAGOAS  NORDESTE        27
# 2     AMAPÁ     NORTE        16
# 3  AMAZONAS     NORTE        13
# 4     BAHIA  NORDESTE        29
#
#                                             geometry sigla_uf  numero_obitos
# 0  POLYGON ((-66.81025 -9.81805, -66.62672 -9.898...       AC           4076
# 1  POLYGON ((-35.15253 -8.91384, -35.30432 -9.190...       AL          20286
# 2  POLYGON ((-50.09391 0.70209, -50.27176 0.68823...       AP           3524
# 3  POLYGON ((-63.37209 2.21186, -63.27635 2.15439...       AM          18321
# 4  POLYGON ((-38.23759 -9.32979, -38.23654 -9.331...       BA          93058

# %%
# Verificando mínimo e máximo para definir range do mapa
obitos_por_UF.numero_obitos.describe()
# Out:
# count        27.000000
# mean      49898.629630
# std       64068.834089
# min        2779.000000
# 25%       15140.500000
# 50%       24406.000000
# 75%       60308.000000
# max      305858.000000
# Name: numero_obitos, dtype: float64

# %% [markdown]
# ##### **3. Elaboração do Mapa**

# %%
# Importando as bibliotecas necessarias
import folium

# %%
# Criando o mapa base
mapa_uf = folium.Map(
    width=800, 
    height=600, 
    location=[-12.97, -38.51], 
    zoom_start=4, 
    tiles="cartodbpositron"
)

# Visualizando o mapa base
mapa_uf
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_26114e07775378e4acfc9ceb716a4272 {
#                     position: relative;
#                     width: 800.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_26114e07775378e4acfc9ceb716a4272&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_26114e07775378e4acfc9ceb716a4272 = L.map(
#                 &quot;map_26114e07775378e4acfc9ceb716a4272&quot;,
#                 {
#                     center: [-12.97, -38.51],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_022331b0f41500b5e81ababc6cb1ab9a = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_26114e07775378e4acfc9ceb716a4272);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Criando a camada Choroplet
mapa = folium.Choropleth(
    geo_data = geo_uf,
    name ='choropleth',
    data = obitos_por_UF,
    columns=['CD_GEOCUF', 'numero_obitos'],
    key_on='feature.properties.CD_GEOCUF',
    fill_color='Greens',
    fill_opacity=0.7,
    line_opacity=0.9,
    legend_name='Óbitos por Unidade da Federação, Brasil, 2019',
    highlight = True,
    reset=True 
).add_to(mapa_uf)

# Renderizando o mapa
mapa_uf
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_26114e07775378e4acfc9ceb716a4272 {
#                     position: relative;
#                     width: 800.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_26114e07775378e4acfc9ceb716a4272&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_26114e07775378e4acfc9ceb716a4272 = L.map(
#                 &quot;map_26114e07775378e4acfc9ceb716a4272&quot;,
#                 {
#                     center: [-12.97, -38.51],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_022331b0f41500b5e81ababc6cb1ab9a = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_26114e07775378e4acfc9ceb716a4272);
#
#
#             var choropleth_e9dda271d5e708b01c4d4c884969ff4e = L.featureGroup(
#                 {}
#             ).addTo(map_26114e07775378e4acfc9ceb716a4272);
#
#
#         function geo_json_a72ea760f5897567827df0a5c8a25023_styler(feature) {
#             switch(feature.id) {
#                 case &quot;4&quot;: case &quot;5&quot;: case &quot;15&quot;: case &quot;16&quot;: case &quot;20&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c7e9c0&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;12&quot;: case &quot;18&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#a1d99b&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;24&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#006d2c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#edf8e9&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.9, &quot;weight&quot;: 1};
#             }
#         }
#         function geo_json_a72ea760f5897567827df0a5c8a25023_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.8999999999999999, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_a72ea760f5897567827df0a5c8a25023_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_a72ea760f5897567827df0a5c8a25023.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_a72ea760f5897567827df0a5c8a25023_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_a72ea760f5897567827df0a5c8a25023 = L.geoJson(null, {
#                 onEachFeature: geo_json_a72ea760f5897567827df0a5c8a25023_onEachFeature,
#
#                 style: geo_json_a72ea760f5897567827df0a5c8a25023_styler,
#         });
#
#         function geo_json_a72ea760f5897567827df0a5c8a25023_add (data) {
#             geo_json_a72ea760f5897567827df0a5c8a25023
#                 .addData(data)
#                 .addTo(choropleth_e9dda271d5e708b01c4d4c884969ff4e);
#         }
#             geo_json_a72ea760f5897567827df0a5c8a25023_add({&quot;bbox&quot;: [-73.96617351599994, -33.74390502800002, -34.8095473749999, 5.271841077000005], &quot;features&quot;: [{&quot;bbox&quot;: [-73.96617351599994, -11.145561466999943, -66.62671969099989, -7.111824378999977], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-66.81025311199988, -9.818045875999971], [-66.62671969099989, -9.898101245000014], [-66.9801989329999, -10.19431558399997], [-67.18033256799991, -10.339460113999955], [-67.3105100489999, -10.320922285999924], [-67.43572846299992, -10.446790359999959], [-67.57903554699993, -10.503396510999941], [-67.70493656899994, -10.699231594000015], [-67.86365695299992, -10.64042424799998], [-68.02089945199992, -10.650235292999955], [-68.27856039799994, -10.989313449999983], [-68.48718609799987, -11.050875333999933], [-68.54297139499988, -11.111355478999908], [-68.7161195959999, -11.145561466999943], [-68.84837791799994, -10.991446527999905], [-69.10253429099997, -10.979946979000022], [-69.40511791399997, -10.927407512999988], [-69.73920890699992, -10.963332661999981], [-69.9325406559999, -10.920607248999993], [-70.14184908299993, -11.029534535999975], [-70

# %%
# Inserindo os rotulos ao passar o mouse
mapa.geojson.add_child(
  folium.features.GeoJsonTooltip(
      fields=['NM_ESTADO', 'numero_obitos'],
      aliases=['Unidade da Federação:', 'Óbitos:'],
      labels=True,
      localize=True,
      sticky=False,
  )
)

# Exibindo o mapa
mapa_uf
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_26114e07775378e4acfc9ceb716a4272 {
#                     position: relative;
#                     width: 800.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_26114e07775378e4acfc9ceb716a4272&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_26114e07775378e4acfc9ceb716a4272 = L.map(
#                 &quot;map_26114e07775378e4acfc9ceb716a4272&quot;,
#                 {
#                     center: [-12.97, -38.51],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_022331b0f41500b5e81ababc6cb1ab9a = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_26114e07775378e4acfc9ceb716a4272);
#
#
#             var choropleth_e9dda271d5e708b01c4d4c884969ff4e = L.featureGroup(
#                 {}
#             ).addTo(map_26114e07775378e4acfc9ceb716a4272);
#
#
#         function geo_json_a72ea760f5897567827df0a5c8a25023_styler(feature) {
#             switch(feature.id) {
#                 case &quot;4&quot;: case &quot;5&quot;: case &quot;15&quot;: case &quot;16&quot;: case &quot;20&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c7e9c0&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;12&quot;: case &quot;18&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#a1d99b&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;24&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#006d2c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#edf8e9&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.9, &quot;weight&quot;: 1};
#             }
#         }
#         function geo_json_a72ea760f5897567827df0a5c8a25023_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.8999999999999999, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_a72ea760f5897567827df0a5c8a25023_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_a72ea760f5897567827df0a5c8a25023.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_a72ea760f5897567827df0a5c8a25023_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_a72ea760f5897567827df0a5c8a25023 = L.geoJson(null, {
#                 onEachFeature: geo_json_a72ea760f5897567827df0a5c8a25023_onEachFeature,
#
#                 style: geo_json_a72ea760f5897567827df0a5c8a25023_styler,
#         });
#
#         function geo_json_a72ea760f5897567827df0a5c8a25023_add (data) {
#             geo_json_a72ea760f5897567827df0a5c8a25023
#                 .addData(data)
#                 .addTo(choropleth_e9dda271d5e708b01c4d4c884969ff4e);
#         }
#             geo_json_a72ea760f5897567827df0a5c8a25023_add({&quot;bbox&quot;: [-73.96617351599994, -33.74390502800002, -34.8095473749999, 5.271841077000005], &quot;features&quot;: [{&quot;bbox&quot;: [-73.96617351599994, -11.145561466999943, -66.62671969099989, -7.111824378999977], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-66.81025311199988, -9.818045875999971], [-66.62671969099989, -9.898101245000014], [-66.9801989329999, -10.19431558399997], [-67.18033256799991, -10.339460113999955], [-67.3105100489999, -10.320922285999924], [-67.43572846299992, -10.446790359999959], [-67.57903554699993, -10.503396510999941], [-67.7049365689999

# %% [markdown]
# ## **Dados agregados por municipio, causa, idade, sexo, raca e ano**

# %%
import pandas as pd

# %%
# Permitir o Google Colab utilizar arquivos do Google Drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
#Lendo o csv salvo no drive
sim = pd.read_csv(
    filepath_or_buffer='/content/drive/MyDrive/Quantitativamente/EBEST2022/municipio_causa_idade_sexo_raca.csv', 
    sep=';'
)

# %%
# Espiando o dataframe
sim.head(3)
# Out:
#    Unnamed: 0   ano sigla_uf  id_municipio causa_basica  idade  sexo  \
# 0           0  2019       PE       2610707         I219   49.0   1.0
# 1           1  2019       PE       2610707         I710   72.0   2.0
# 2           2  2019       PE       2610707         J159   48.0   1.0
#
#    raca_cor  numero_obitos
# 0       4.0              1
# 1       2.0              1
# 2       4.0              1

# %%
# Espiando a estrutura do dataframe
sim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22618604 entries, 0 to 22618603
# Data columns (total 9 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   Unnamed: 0     int64
#  1   ano            int64
#  2   sigla_uf       object
#  3   id_municipio   int64
#  4   causa_basica   object
#  5   idade          float64
#  6   sexo           float64
#  7   raca_cor       float64
#  8   numero_obitos  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.5+ GB

# %%
# Gerando Tabela de frequência das causas de mortes
sim.causa_basica.value_counts(normalize=True)
# Out:
# I219    5.424650e-02
# R98     3.846603e-02
# I64     3.728272e-02
# R99     3.050140e-02
# J189    2.484645e-02
#             ...
# D562    4.421139e-08
# V663    4.421139e-08
# X417    4.421139e-08
# O332    4.421139e-08
# X118    4.421139e-08
# Name: causa_basica, Length: 8581, dtype: float64

# %%
# Gerando Tabela de frequência das causas de mortes
# Transformando num dataframe
tab_causas_mortes = sim\
  .groupby('causa_basica', as_index = True)\
  .agg({"numero_obitos": "sum"})\
  .sort_values('numero_obitos', ascending=False)\
  .reset_index()

# Espiando o dataframe resultante
tab_causas_mortes.head(20)
# Out:
#    causa_basica  numero_obitos
# 0          I219        1752847
# 1           R98        1048603
# 2           I64        1028021
# 3           R99         901727
# 4          J189         735421
# 5          E149         563627
# 6          J449         477645
# 7          C349         472431
# 8           I10         417582
# 9          X954         348625
# 10         I500         348186
# 11         I619         328997
# 12         J180         323221
# 13         A419         320241
# 14         X959         294077
# 15         C169         291136
# 16         I694         277753
# 17         C509         277430
# 18         I678         275143
# 19          C61         270161

# %% [markdown]
# #### **Óbitos em decorrência de câncer de mama por ano no Brasil**

# %% [markdown]
# https://www.medicinanet.com.br/cid10/1303/c50_neoplasia_maligna_da_mama.htm

# %%
# Definindo lista de CID associada a neoplasia maligna da mama 
list_cid_cm = ['C50','C500','C501','C502','C503','C504','C505','C506','C507','C508','C509']

# Filtrando os dados do SIM para causas básicas associado ao CID50
ocm = sim.query("causa_basica in @list_cid_cm")

# Espiando o df resultante
ocm
# Out:
#           Unnamed: 0   ano sigla_uf  id_municipio causa_basica  idade  sexo  \
# 27                27  2019       PE       2611606         C509   67.0   2.0
# 28                28  2019       PE       2611606         C509   93.0   2.0
# 265              265  2017       PA       1505403         C509   87.0   2.0
# 341              341  2015       CE       2311603         C509   47.0   2.0
# 471              471  2018       PE       2613008         C509   57.0   2.0
# ...              ...   ...      ...           ...          ...    ...   ...
# 22618132    22618132  2015       SP       3504107         C509   93.0   2.0
# 22618209    22618209  2015       SP       3509502         C509   49.0   2.0
# 22618485    22618485  2011       SP       3504503         C509   74.0   2.0
# 22618549    22618549  2011       SP       3508603         C509   52.0   2.0
# 22618564    22618564  2011       SP       3509502         C509   81.0   2.0
#
#           raca_cor  numero_obitos
# 27             2.0              1
# 28             4.0              1
# 265            4.0              1
# 341            1.0              1
# 471            1.0              1
# ...            ...            ...
# 22618132       1.0              1
# 22618209       1.0              2
# 22618485       1.0              1
# 22618549       4.0              1
# 22618564       NaN              1
#
# [215599 rows x 9 columns]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Inserindo os labels na variavel sexo
ocm['sexo_label'] = ocm['sexo'].replace([1,2,0,9],['Masculino','Feminino','Outros','Outros']);

# Inserindo os labels na variavel raca_cor
ocm['raca_cor_label'] = ocm['raca_cor']\
  .replace([1,2,3,4,5],['Branca','Preta','Amarela','Parda','Indigena']);

# Espiando o df resultante
ocm.head(5)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      Unnamed: 0   ano sigla_uf  id_municipio causa_basica  idade  sexo  \
# 27           27  2019       PE       2611606         C509   67.0   2.0
# 28           28  2019       PE       2611606         C509   93.0   2.0
# 265         265  2017       PA       1505403         C509   87.0   2.0
# 341         341  2015       CE       2311603         C509   47.0   2.0
# 471         471  2018       PE       2613008         C509   57.0   2.0
#
#      raca_cor  numero_obitos sexo_label raca_cor_label
# 27        2.0              1   Feminino          Preta
# 28        4.0              1   Feminino          Parda
# 265       4.0              1   Feminino          Parda
# 341       1.0              1   Feminino         Branca
# 471       1.0              1   Feminino         Branca

# %%
# Apagando as colunas que não serão utilizadas
ocm = ocm.drop(columns=['Unnamed: 0','sexo','raca_cor'], axis=1)

# Espiando o df resultante
ocm.head(5)
# Out:
#       ano sigla_uf  id_municipio causa_basica  idade  numero_obitos  \
# 27   2019       PE       2611606         C509   67.0              1
# 28   2019       PE       2611606         C509   93.0              1
# 265  2017       PA       1505403         C509   87.0              1
# 341  2015       CE       2311603         C509   47.0              1
# 471  2018       PE       2613008         C509   57.0              1
#
#     sexo_label raca_cor_label
# 27    Feminino          Preta
# 28    Feminino          Parda
# 265   Feminino          Parda
# 341   Feminino         Branca
# 471   Feminino         Branca

# %% [markdown]
# ##### **Óbitos decorrente câncer de mama por sexo no Brasil em 2019**

# %%
# Importando as bibliotecas necessarias
import plotly.express as px

# %%
# Criando a tabela com distribuição dos óbitos por sexo
tab_sexo = ocm.query('ano==2019')\
  .groupby('sexo_label', as_index = True)\
  .agg({"numero_obitos": "sum"})\
  .sort_values('numero_obitos', ascending=False)\
  .reset_index()

# Espiando o dataframe resultante
tab_sexo
# Out:
#   sexo_label  numero_obitos
# 0   Feminino          18063
# 1  Masculino            227
# 2     Outros              1

# %%
# Calculando porcentagem
tab_sexo['pct'] = (tab_sexo['numero_obitos'])\
                        .div(tab_sexo['numero_obitos'].sum()) \
                        .mul(100)\
                        .round(2)

# Espiando o resultado
tab_sexo
# Out:
#   sexo_label  numero_obitos    pct
# 0   Feminino          18063  98.75
# 1  Masculino            227   1.24
# 2     Outros              1   0.01

# %%
 # Construindo o Gráfico de pizza
px.pie(
    data_frame = tab_sexo, 
    values='pct', 
    names='sexo_label', 
    title='Óbitos por neoplasia maligna da mama, por sexo, Brasil, 2019.'
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d8ee7900-6e9b-4835-8d05-1e7fbf4204a2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d8ee7900-6e9b-4835-8d05-1e7fbf4204a2")) {                    Plotly.newPlot(                        "d8ee7900-6e9b-4835-8d05-1e7fbf4204a2",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"sexo_label=%{label}<br>pct=%{value}<extra></extra>","labels":["Feminino","Masculino","Outros"],"legendgroup":"","name":"","showlegend":true,"values":[98.75,1.24,0.01],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"sc ...

# %%
 # Construindo o Gráfico de pizza
px.pie(
    data_frame = tab_sexo, 
    values='pct', 
    names='sexo_label', 
    title='Óbitos por neoplasia maligna da mama, por sexo, Brasil, 2019.',
    color_discrete_sequence = px.colors.sequential.Sunsetdark
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="2ca33b58-dd3d-4c7f-8677-67523f2d5f83" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2ca33b58-dd3d-4c7f-8677-67523f2d5f83")) {                    Plotly.newPlot(                        "2ca33b58-dd3d-4c7f-8677-67523f2d5f83",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"sexo_label=%{label}<br>pct=%{value}<extra></extra>","labels":["Feminino","Masculino","Outros"],"legendgroup":"","name":"","showlegend":true,"values":[98.75,1.24,0.01],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"sc ...

# %%
 # Construindo o Gráfico de pizza
px.pie(
    data_frame = tab_sexo, 
    title='Óbitos por neoplasia maligna da mama, por sexo, Brasil, 2019.',
    values='pct', 
    names='sexo_label', 
    color = 'sexo_label',
    color_discrete_map = { 
      'Feminino' : 'darkorange' , 
      'Masculino' : 'darkblue',
      'Outros' : 'grey'
    }
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="711fe6ca-3324-4c66-b57d-bb9b878317f1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("711fe6ca-3324-4c66-b57d-bb9b878317f1")) {                    Plotly.newPlot(                        "711fe6ca-3324-4c66-b57d-bb9b878317f1",                        [{"customdata":[["Feminino"],["Masculino"],["Outros"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"sexo_label=%{customdata[0]}<br>pct=%{value}<extra></extra>","labels":["Feminino","Masculino","Outros"],"legendgroup":"","marker":{"colors":["darkorange","darkblue","grey"]},"name":"","showlegend":true,"values":[98.75,1.24,0.01],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"col ...

# %%
 # Construindo o Gráfico de pizza
px.pie(
    data_frame = tab_sexo, 
    title='Óbitos por neoplasia maligna da mama, por sexo, Brasil, 2019.',
    values='pct', 
    names='sexo_label', 
    color = 'sexo_label',
    color_discrete_map = { 
      'Feminino' : 'darkgreen' , 
      'Masculino' : 'lightgray',
      'Outros' : 'red'
    },
    labels={'sexo_label':'Sexo'},
    opacity = 1,
    width=600, 
    height=400
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4406468f-5056-41ae-a5fb-13752788a01e" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4406468f-5056-41ae-a5fb-13752788a01e")) {                    Plotly.newPlot(                        "4406468f-5056-41ae-a5fb-13752788a01e",                        [{"customdata":[["Feminino"],["Masculino"],["Outros"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Sexo=%{customdata[0]}<br>pct=%{value}<extra></extra>","labels":["Feminino","Masculino","Outros"],"legendgroup":"","marker":{"colors":["darkgreen","lightgray","red"]},"name":"","opacity":1,"showlegend":true,"values":[98.75,1.24,0.01],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line" ...

# %%
# Construindo o Gráfico de pizza
px.pie(
    data_frame = tab_sexo, 
    title = '<b>Óbitos por neoplasia maligna da mama, por sexo</b><br>Brasil, 2019.',
    values='pct', 
    names='sexo_label', 
    color = 'sexo_label',
    color_discrete_map = { 
      'Feminino' : 'darkgreen' , 
      'Masculino' : 'lightgray', 
      'Outros' : 'red'
    },
    labels={'sexo_label':'Sexo'},
    opacity = 1,
    width=800, 
    height=600,
    hole=.5
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="404487c0-6f1e-4914-8b38-9df4d52b6819" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("404487c0-6f1e-4914-8b38-9df4d52b6819")) {                    Plotly.newPlot(                        "404487c0-6f1e-4914-8b38-9df4d52b6819",                        [{"customdata":[["Feminino"],["Masculino"],["Outros"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.5,"hovertemplate":"Sexo=%{customdata[0]}<br>pct=%{value}<extra></extra>","labels":["Feminino","Masculino","Outros"],"legendgroup":"","marker":{"colors":["darkgreen","lightgray","red"]},"name":"","opacity":1,"showlegend":true,"values":[98.75,1.24,0.01],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3 ...

# %% [markdown]
# ##### **Óbitos decorrente câncer de mama por Raça/Cor no Brasil em 2019**

# %%
# Criando a tabela com distribuição dos óbitos por raca_cor
tab_raca_cor = ocm.query('ano==2019')\
  .groupby('raca_cor_label', as_index = True)\
  .agg({"numero_obitos": "sum"})\
  .reset_index()

# Espiando o dataframe resultante
tab_raca_cor
# Out:
#   raca_cor_label  numero_obitos
# 0        Amarela             95
# 1         Branca          10517
# 2       Indigena             19
# 3          Parda           5799
# 4          Preta           1436

# %%
# Calculando porcentagem
tab_raca_cor['pct'] = (tab_raca_cor['numero_obitos'])\
                        .div(tab_raca_cor['numero_obitos'].sum()) \
                        .mul(100)\
                        .round(2)

# Espiando o resultado
tab_raca_cor
# Out:
#   raca_cor_label  numero_obitos    pct
# 0        Amarela             95   0.53
# 1         Branca          10517  58.87
# 2       Indigena             19   0.11
# 3          Parda           5799  32.46
# 4          Preta           1436   8.04

# %%
# Importando de forma explícitas as bibliotecas
import bokeh.io
import bokeh.plotting

# Habilitando a visualização de gráficos gerados pelo Bokeh em Notebooks
bokeh.io.output_notebook()

# %%
# Definindo configurações principais do gráficos
graf_raca_cor = bokeh.plotting.figure(
    title="Óbitos por neoplasia maligna da mama, por Raça/Cor, Brasil, 2019.",
    width=600,
    height=400,
    x_axis_label="Raça/Cor",
    y_axis_label="Óbitos (em %)",
    x_range = tab_raca_cor['raca_cor_label'],
    y_range= (0, 65)
)

# Elaborando o gráfico de barras
graf_raca_cor.vbar(
    source = tab_raca_cor,
    x = 'raca_cor_label', #tab_raca_cor['raca_cor_label'], 
    top = 'pct', #tab_raca_cor['pct'],
    width  = 0.8, 
    line_color="darkblue", 
    line_width=2,
    fill_color="blue"
)

# Inserindo textos
graf_raca_cor.text(
    x = tab_raca_cor['raca_cor_label'], 
    y = tab_raca_cor['pct'], 
    text = tab_raca_cor['pct'],
    text_font_style = 'bold',
    text_color = "darkblue",
    text_font_size = {'value': '12px'}
)

# Exibindo o gráfico de linhas com os marcadores
bokeh.io.show(graf_raca_cor)
# Out:
#   <div class="bk-root" id="0d599718-a290-4362-bec1-b363dc0b95cf" data-root-id="1442"></div>

# %%
# Ordenando a tabela
tab_raca_cor = tab_raca_cor.sort_values('numero_obitos')

# Definindo configurações principais do gráficos
graf_raca_cor2 = bokeh.plotting.figure(
    title="Óbitos por neoplasia maligna da mama, por Raça/Cor, Brasil, 2019.",
    width=600,
    height=400,
    y_axis_label="Raça/Cor",
    x_axis_label="Óbitos (em %)",
    x_range = (0, 65),
    y_range= tab_raca_cor['raca_cor_label']
)


# Elaborando o gráfico de barras
graf_raca_cor2.hbar(
    source = tab_raca_cor,
    y = 'raca_cor_label', #tab_raca_cor['raca_cor_label'], 
    right = 'pct', #tab_raca_cor['pct'],
    height  = 0.9, 
    line_color="darkgreen", 
    line_width=2,
    fill_color="green"
)

# Inserindo textos
graf_raca_cor2.text(
    y = tab_raca_cor['raca_cor_label'], 
    x = tab_raca_cor['pct']+0.2, 
    text = tab_raca_cor['pct'],
    text_font_style = 'bold',
    text_color = "darkgreen",
    text_font_size = {'value': '12px'}
)


# Exibindo o gráfico de linhas com os marcadores
bokeh.io.show(graf_raca_cor2)
# Out:
#   <div class="bk-root" id="a55545e4-cee7-41d3-aaa7-66359714931c" data-root-id="2142"></div>

# %% [markdown]
# ##### **Óbitos decorrente câncer de mama por Causa no Brasil em 2019**

# %%
# Inserindo os labels da causa
ocm['causa_basica_label'] = ocm['causa_basica']\
  .replace(
    ['C500','C501','C502','C503','C504','C505','C506','C508','C509'],
    ['mamilo e aréola','porção central da mama','quadrante superior interno da mama','quadrante inferior interno da mama','quadrante superior externo da mama','quadrante inferior externo da mama','porção axilar da mama','mama com lesão invasiva','mama, não especificada']
  );

# Espiando o df resultante
ocm.head(5)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#      Unnamed: 0   ano sigla_uf  id_municipio causa_basica  idade  sexo  \
# 27           27  2019       PE       2611606         C509   67.0   2.0
# 28           28  2019       PE       2611606         C509   93.0   2.0
# 265         265  2017       PA       1505403         C509   87.0   2.0
# 341         341  2015       CE       2311603         C509   47.0   2.0
# 471         471  2018       PE       2613008         C509   57.0   2.0
#
#      raca_cor  numero_obitos sexo_label raca_cor_label      causa_basica_label
# 27        2.0              1   Feminino          Preta  mama, não especificada
# 28        4.0              1   Feminino          Parda  mama, não especificada
# 265       4.0              1   Feminino          Parda  mama, não especificada
# 341       1.0              1   Feminino         Branca  mama, não especificada
# 471       1.0              1   Feminino         Branca  mama, não especificada

# %%
# Criando a tabela com distribuição dos óbitos por raca_cor
tab_causa = ocm.query('ano==2019')\
  .groupby('causa_basica_label', as_index = True)\
  .agg({"numero_obitos": "sum"})\
  .sort_values('numero_obitos')\
  .reset_index()

# Calculando porcentagem
tab_causa['pct'] = (tab_causa['numero_obitos'])\
                        .div(tab_causa['numero_obitos'].sum()) \
                        .mul(100)\
                        .round(2)

# Espiando o resultado
tab_causa
# Out:
#                    causa_basica_label  numero_obitos    pct
# 0               porção axilar da mama             12   0.07
# 1  quadrante inferior interno da mama             13   0.07
# 2  quadrante inferior externo da mama             14   0.08
# 3  quadrante superior interno da mama             16   0.09
# 4  quadrante superior externo da mama             29   0.16
# 5              porção central da mama             53   0.29
# 6                     mamilo e aréola            135   0.74
# 7             mama com lesão invasiva            991   5.42
# 8              mama, não especificada          17028  93.09

# %%
# Importando as bibliotecas necessarias
import altair as alt

# %%
# Definindo as barras
bars = alt.Chart(
    data=tab_causa,
    height=600, 
    title = 'Óbitos por neoplasia maligna da mama, por Raça/Cor, Brasil, 2019.'
  ).mark_bar()\
  .encode(
    x=alt.X(
    shorthand = "pct:Q", 
    axis = alt.Axis(title = 'Óbito (em %))')
    ), 
    y=alt.Y(
        shorthand = "causa_basica_label:O", 
        sort='-x', 
        axis = alt.Axis(title = 'Causa do óbito: Neoplasia Maligna da')
  )    
)

# Definindo os rótulos
text = bars.mark_text(
    align='left',
    baseline='middle',
    dx=4
  ).encode(text='pct:Q')

# Fazendo o gráfico de barras
(bars + text)\
  .configure_mark(opacity=0.9,color='deeppink')
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ##### **Óbitos decorrente câncer de mama no Brasil em 1996-2019**

# %%
# Criando a tabela com distribuição dos óbitos por raca_cor
tab_causa_ano = ocm\
  .groupby('ano', as_index = True)\
  .agg({"numero_obitos": "sum"})\
  .reset_index()

# Espiando o resultado
tab_causa_ano
# Out:
#      ano  numero_obitos
# 0   1996           7163
# 1   1997           7664
# 2   1998           8050
# 3   1999           8174
# 4   2000           8393
# 5   2001           8743
# 6   2002           9082
# 7   2003           9414
# 8   2004           9876
# 9   2005          10270
# 10  2006          10941
# 11  2007          11188
# 12  2008          11941
# 13  2009          12079
# 14  2010          12845
# 15  2011          13338
# 16  2012          13742
# 17  2013          14380
# 18  2014          14782
# 19  2015          15591
# 20  2016          16250
# 21  2017          16921
# 22  2018          17760
# 23  2019          18291

# %%
# Fazendo gráfico de área
alt.Chart(data = tab_causa_ano) \
 .mark_area(
    line={'color':'purple'},
    color=alt.Gradient(
        gradient='linear',
        stops=[alt.GradientStop(color='white', offset=0),
               alt.GradientStop(color='pink', offset=1)],
        x1=1,
        x2=1,
        y1=1,
        y2=0
    )
).encode(
    x=alt.X(
    shorthand = 'ano:T', 
    axis = alt.Axis(title = 'Ano')
    ), 
    y=alt.Y(
        shorthand = 'numero_obitos:Q', 
        sort='-x', 
        axis = alt.Axis(title = 'Óbitos')
    )
).properties(width=600, height=400, title = 'Óbitos por neoplasia maligna da mama, Brasil, 1996-2019')
# Out:
# alt.Chart(...)

# %% [markdown]
# ##### **Óbitos decorrente câncer de mama por idade no Brasil em 2019**

# %%
# Importando as bibliotecas necessarias
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ocm.tail(20)
# Out:
#           Unnamed: 0   ano sigla_uf  id_municipio causa_basica  idade  sexo  \
# 22616759    22616759  2002       SP       3503208         C509   55.0   2.0
# 22616835    22616835  2002       SP       3508504         C509   53.0   2.0
# 22616947    22616947  2006       SP       3503208         C509   76.0   2.0
# 22617027    22617027  2006       SP       3508603         C508   69.0   2.0
# 22617116    22617116  2003       SP       3502804         C509   69.0   2.0
# 22617190    22617190  2003       SP       3508603         C509   68.0   2.0
# 22617284    22617284  1999       SP       3504008         C509   67.0   2.0
# 22617356    22617356  1999       SP       3509502         C509   71.0   2.0
# 22617528    22617528  2009       SP       3506805         C509   41.0   2.0
# 22617636    22617636  2017       SP       3503307         C509   63.0   1.0
# 22617662    22617662  2017       SP       3505708         C509   55.0   2.0
# 22617711    22617711  2017       SP       3508504         C509   75.0   2.0
# 22617718    22617718  2017       SP       3509502         C509   27.0   2.0
# 22617989    22617989  2010       SP       3506003         C509   72.0   2.0
# 22618096    22618096  2015       SP       3501608         C509   62.0   2.0
# 22618132    22618132  2015       SP       3504107         C509   93.0   2.0
# 22618209    22618209  2015       SP       3509502         C509   49.0   2.0
# 22618485    22618485  2011       SP       3504503         C509   74.0   2.0
# 22618549    22618549  2011       SP       3508603         C509   52.0   2.0
# 22618564    22618564  2011       SP       3509502         C509   81.0   2.0
#
#           raca_cor  numero_obitos sexo_label raca_cor_label  \
# 22616759       1.0              2   Feminino         Branca
# 22616835       4.0              1   Feminino          Parda
# 22616947       1.0              1   Feminino         Branca
# 22617027       1.0              1   Feminino         Branca
# 22617116       1.0              1   Feminino         Branca
# 22617190       1.0              1   Feminino         Branca
# 22617284       1.0              1   Feminino         Branca
# 22617356       1.0              3   Feminino         Branca
# 22617528       1.0              1   Feminino         Branca
# 22617636       1.0              1  Masculino         Branca
# 22617662       4.0              1   Feminino          Parda
# 22617711       1.0              1   Feminino         Branca
# 22617718       1.0              1   Feminino         Branca
# 22617989       1.0              1   Feminino         Branca
# 22618096       1.0              1   Feminino         Branca
# 22618132       1.0              1   Feminino         Branca
# 22618209       1.0              2   Feminino         Branca
# 22618485       1.0              1   Feminino         Branca
# 22618549       4.0              1   Feminino          Parda
# 22618564       NaN              1   Feminino            NaN
#
#                causa_basica_label
# 22616759   mama, não especificada
# 22616835   mama, não especificada
# 22616947   mama, não especificada
# 22617027  mama com lesão invasiva
# 22617116   mama, não especificada
# 22617190   mama, não especificada
# 22617284   mama, não especificada
# 22617356   mama, não especificada
# 22617528   mama, não especificada
# 22617636   mama, não especificada
# 22617662   mama, não especificada
# 22617711   mama, não especificada
# 22617718   mama, não especificada
# 22617989   mama, não especificada
# 22618096   mama, não especificada
# 22618132   mama, não especificada
# 22618209   mama, não especificada
# 22618485   mama, não especificada
# 22618549   mama, não especificada
# 22618564   mama, não especificada

# %%
# Definindo função para repetir registros
def reindex_df(df, weight_col):
    df = df.reindex(df.index.repeat(df[weight_col]))
    df.reset_index(drop=True, inplace=True)
    return(df)

# %%
# Refazendo o dataframe repetindo as idades
ocm_desagregado = reindex_df(ocm, weight_col = 'numero_obitos')
ocm_desagregado.tail(20)
# Out:
#         Unnamed: 0   ano sigla_uf  id_municipio causa_basica  idade  sexo  \
# 286858    22617027  2006       SP       3508603         C508   69.0   2.0
# 286859    22617116  2003       SP       3502804         C509   69.0   2.0
# 286860    22617190  2003       SP       3508603         C509   68.0   2.0
# 286861    22617284  1999       SP       3504008         C509   67.0   2.0
# 286862    22617356  1999       SP       3509502         C509   71.0   2.0
# 286863    22617356  1999       SP       3509502         C509   71.0   2.0
# 286864    22617356  1999       SP       3509502         C509   71.0   2.0
# 286865    22617528  2009       SP       3506805         C509   41.0   2.0
# 286866    22617636  2017       SP       3503307         C509   63.0   1.0
# 286867    22617662  2017       SP       3505708         C509   55.0   2.0
# 286868    22617711  2017       SP       3508504         C509   75.0   2.0
# 286869    22617718  2017       SP       3509502         C509   27.0   2.0
# 286870    22617989  2010       SP       3506003         C509   72.0   2.0
# 286871    22618096  2015       SP       3501608         C509   62.0   2.0
# 286872    22618132  2015       SP       3504107         C509   93.0   2.0
# 286873    22618209  2015       SP       3509502         C509   49.0   2.0
# 286874    22618209  2015       SP       3509502         C509   49.0   2.0
# 286875    22618485  2011       SP       3504503         C509   74.0   2.0
# 286876    22618549  2011       SP       3508603         C509   52.0   2.0
# 286877    22618564  2011       SP       3509502         C509   81.0   2.0
#
#         raca_cor  numero_obitos sexo_label raca_cor_label  \
# 286858       1.0              1   Feminino         Branca
# 286859       1.0              1   Feminino         Branca
# 286860       1.0              1   Feminino         Branca
# 286861       1.0              1   Feminino         Branca
# 286862       1.0              3   Feminino         Branca
# 286863       1.0              3   Feminino         Branca
# 286864       1.0              3   Feminino         Branca
# 286865       1.0              1   Feminino         Branca
# 286866       1.0              1  Masculino         Branca
# 286867       4.0              1   Feminino          Parda
# 286868       1.0              1   Feminino         Branca
# 286869       1.0              1   Feminino         Branca
# 286870       1.0              1   Feminino         Branca
# 286871       1.0              1   Feminino         Branca
# 286872       1.0              1   Feminino         Branca
# 286873       1.0              2   Feminino         Branca
# 286874       1.0              2   Feminino         Branca
# 286875       1.0              1   Feminino         Branca
# 286876       4.0              1   Feminino          Parda
# 286877       NaN              1   Feminino            NaN
#
#              causa_basica_label
# 286858  mama com lesão invasiva
# 286859   mama, não especificada
# 286860   mama, não especificada
# 286861   mama, não especificada
# 286862   mama, não especificada
# 286863   mama, não especificada
# 286864   mama, não especificada
# 286865   mama, não especificada
# 286866   mama, não especificada
# 286867   mama, não especificada
# 286868   mama, não especificada
# 286869   mama, não especificada
# 286870   mama, não especificada
# 286871   mama, não especificada
# 286872   mama, não especificada
# 286873   mama, não especificada
# 286874   mama, não especificada
# 286875   mama, não especificada
# 286876   mama, não especificada
# 286877   mama, não especificada

# %%
# Elaborando um histograma da idade
sns.histplot(data = ocm_desagregado,  x = 'idade');

# %%
# Elaborando um gráfico histograma com ajustes

# Definindo o tamanho da figura
fig, ax = plt.subplots(figsize =(9, 7))

# Fazendo o gráfico de Colunas
ax = sns.histplot(
    data=ocm_desagregado, 
    x = 'idade', 
    stat = 'percent', 
    bins = 20, 
    color = 'purple'
);

# Inserindo o título
ax.set_title(
  label = 'Distribuição da idade das pessoas que foram a Óbito por neoplasia maligna da mama, por sexo, Brasil, 1996-2019.', 
  loc ='left'
);

# Inserindo titulos dos eixos
plt.xlabel("Idade");
plt.ylabel("Óitos (em %)");

# %%
# Desenhando o Boxplot da idade
sns.boxplot(data = ocm_desagregado, y="idade", color = 'deeppink');

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Calculando algumas estatísticas descritivas da idade
ocm_desagregado.idade.describe()
# Out:
# count    286794.000000
# mean         60.781945
# std          15.152433
# min           0.000000
# 25%          50.000000
# 50%          60.000000
# 75%          72.000000
# max         115.000000
# Name: idade, dtype: float64

# %%
# Definindo o tamanho da figura
fig, ax = plt.subplots(figsize =(15, 8))

# Desenhando o Boxplot
ax = sns.boxplot(
    data = ocm_desagregado,
    x="sexo_label", 
    y="idade" 
)

# Inserindo o título
ax.set_title(
    label = 'Distribuição da idade das pessoas que foram a Óbito por neoplasia maligna da mama, por sexo, Brasil, 1996-2019', 
    loc ='left'
)

# Inserindo rótulos dos eixos
plt.xlabel("Sexo")
plt.ylabel("Idade")

# Exibindo o gráfico
plt.show()

# %%
# Definindo o tamanho da figura
fig, ax = plt.subplots(figsize =(15, 8))

# Desenhando o Boxplot
ax = sns.boxplot(
    data = ocm_desagregado,
    x="ano", 
    y="idade" 
)

# Inserindo o título
ax.set_title(
    label = 'Distribuição da idade das pessoas que foram a Óbito por neoplasia maligna da mama, Brasil, 1996-2019', 
    loc ='left'
)

# Inserindo rótulos dos eixos
plt.xlabel("ano")
plt.ylabel("Idade")

# Exibindo o gráfico
plt.show()

# %%
# Criando a tabela com distribuição dos óbitos por raca_cor
tab_idade_ano = ocm_desagregado\
  .groupby('ano', as_index = True)\
  .agg({"idade": "mean"})\
  .reset_index()

# Espiando o resultado
tab_idade_ano
# Out:
#      ano      idade
# 0   1996  59.097216
# 1   1997  59.034514
# 2   1998  59.291579
# 3   1999  59.275934
# 4   2000  59.432046
# 5   2001  59.551310
# 6   2002  59.504353
# 7   2003  60.079596
# 8   2004  59.916354
# 9   2005  60.141605
# 10  2006  60.404699
# 11  2007  60.494815
# 12  2008  60.500168
# 13  2009  60.493583
# 14  2010  60.819385
# 15  2011  60.890530
# 16  2012  61.104359
# 17  2013  61.103902
# 18  2014  61.294412
# 19  2015  61.676416
# 20  2016  61.541264
# 21  2017  61.946099
# 22  2018  62.288345
# 23  2019  62.311827

# %%
# Gráfico de linhas da idade ao longo do tempo
tab_idade_ano.plot.line(
    x="ano", 
    y="idade",
    color = 'purple',
    marker='p',
    figsize=(10, 6),
    ylabel='Idade',
    xlabel='Ano',
    title = 'Distribuição da idade das pessoas que foram a Óbito por neoplasia maligna da mama, Brasil, 1996-2019',
);

# %%
# Definindo o tamanho da figura
fig, ax = plt.subplots(figsize =(10, 8))

# Desenhando o Boxplot
ax = sns.boxplot(
    data = ocm_desagregado,
    x="raca_cor_label", 
    y="idade",
    palette = 'Spectral' 
)

# Inserindo o título
ax.set_title(
    label = 'Distribuição da idade das pessoas que foram a Óbito por neoplasia maligna da mama, por sexo, Brasil, 1996-2019', 
    loc ='left'
)

# Inserindo rótulos dos eixos
plt.xlabel("Raça / Cor")
plt.ylabel("Idade")

# Exibindo o gráfico
plt.show()

# %%
# Criando a tabela com distribuição da idade por raca_cor das pessoas que vieraram a óbito 
tab_idade_raca = ocm_desagregado\
  .groupby('raca_cor_label', as_index = True)\
  .agg({"idade": "mean"})\
  .reset_index()

# Espiando o resultado
tab_idade_raca
# Out:
#   raca_cor_label      idade
# 0        Amarela  63.393209
# 1         Branca  62.235565
# 2       Indigena  58.312757
# 3          Parda  57.911605
# 4          Preta  59.377937

# %%
# Criando a tabela com distribuição da idade por raca_cor das pessoas que vieraram a óbito 
ocm_desagregado\
  .filter(items=['raca_cor_label','idade'])\
  .groupby('raca_cor_label', as_index = True)\
  .describe()
# Out:
#                    idade
#                    count       mean        std   min   25%   50%   75%    max
# raca_cor_label
# Amarela           2032.0  63.393209  15.049481   0.0  52.0  63.0  74.0  105.0
# Branca          170492.0  62.235565  15.229327  13.0  51.0  62.0  74.0  112.0
# Indigena           243.0  58.312757  15.673348  24.0  46.5  58.0  69.0   98.0
# Parda            67119.0  57.911605  14.680195   0.0  47.0  57.0  68.0  110.0
# Preta            19363.0  59.377937  14.648610   0.0  49.0  58.0  70.0  105.0

# %%
# Definindo o tamanho da figura
fig, ax = plt.subplots(figsize =(10, 6))

# Desenhando o Boxplot
ax = sns.barplot(
    data=ocm_desagregado, 
    x="raca_cor_label", 
    y="idade",
    palette = 'Spectral' 
)

# Inserindo o título
ax.set_title(
    label = 'Distribuição da idade das pessoas que foram a Óbito por neoplasia maligna da mama, por Raça / Cor, Brasil, 1996-2019', 
    loc ='left'
)

# Inserindo rótulos dos eixos
plt.xlabel("Raça / Cor")
plt.ylabel("Idade")

# Exibindo o gráfico
plt.show()

# %% [markdown]
# ##### **Óbitos decorrente câncer de mama por Unidade da Federação no Brasil em 2019**

# %% [markdown]
# ###### **1. Organização dos dados geoespaciais**

# %%
#Instalando o Geopandas
# !pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting geopandas
#   Downloading geopandas-0.10.2-py2.py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 4.6 MB/s
# Collecting fiona>=1.8
#   Downloading Fiona-1.8.22-cp37-cp37m-manylinux2014_x86_64.whl (16.7 MB)
#      |████████████████████████████████| 16.7 MB 576 kB/s
# Collecting pyproj>=2.2.0
#   Downloading pyproj-3.2.1-cp37-cp37m-manylinux2010_x86_64.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 37.5 MB/s
# Requirement already satisfied: shapely>=1.6 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.8.5.post1)
# Requirement already satisfied: pandas>=0.25.0 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.3.5)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (57.4.0)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (22.1.0)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (7.1.2)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (1.15.0)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (2022.9.24)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (2022.4)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (2.8.2)
# Installing collected packages: munch, cligj, click-plugins, pyproj, fiona, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.7.2 fiona-1.8.22 geopandas-0.10.2 munch-2.5.0 pyproj-3.2.1

# %%
# Importando bibliotecas necessárias
import geopandas as gpd
import json

# %%
# Pegando o geojson
url_geojson = 'https://raw.githubusercontent.com/jonates/opendata/master/arquivos_geoespaciais/unidades_da_federacao.json'
geo_uf = gpd.read_file(url_geojson)

# %%
# Espiando a estrutura do objeto
geo_uf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   NM_ESTADO  27 non-null     object
#  1   NM_REGIAO  27 non-null     object
#  2   CD_GEOCUF  27 non-null     object
#  3   geometry   27 non-null     geometry
# dtypes: geometry(1), object(3)
# memory usage: 992.0+ bytes

# %%
#Espiando o objeto geoespacial
geo_uf.head()
# Out:
#   NM_ESTADO NM_REGIAO CD_GEOCUF  \
# 0      ACRE     NORTE        12
# 1   ALAGOAS  NORDESTE        27
# 2     AMAPÁ     NORTE        16
# 3  AMAZONAS     NORTE        13
# 4     BAHIA  NORDESTE        29
#
#                                             geometry
# 0  POLYGON ((-66.81025 -9.81805, -66.62672 -9.898...
# 1  POLYGON ((-35.15253 -8.91384, -35.30432 -9.190...
# 2  POLYGON ((-50.09391 0.70209, -50.27176 0.68823...
# 3  POLYGON ((-63.37209 2.21186, -63.27635 2.15439...
# 4  POLYGON ((-38.23759 -9.32979, -38.23654 -9.331...

# %% [markdown]
# ###### **2. Organização do dataframe**

# %%
# Criando a tabela com distribuição dos óbitos por raca_cor
tab_uf = ocm.query('ano==2019')\
  .groupby('sigla_uf', as_index = True)\
  .agg({"numero_obitos": "sum"})\
  .sort_values('numero_obitos')\
  .reset_index()

# Espiando o resultado
tab_uf
# Out:
#    sigla_uf  numero_obitos
# 0        RR             24
# 1        AP             25
# 2        AC             34
# 3        TO             70
# 4        RO             93
# 5        SE            177
# 6        AM            187
# 7        MT            202
# 8        AL            208
# 9        PI            211
# 10       MS            226
# 11       DF            252
# 12       MA            268
# 13       RN            272
# 14       PB            306
# 15       PA            335
# 16       ES            363
# 17       GO            523
# 18       SC            673
# 19       CE            773
# 20       PE            830
# 21       PR           1015
# 22       BA           1064
# 23       RS           1428
# 24       MG           1728
# 25       RJ           2298
# 26       SP           4706

# %%
# Inserindo o codigo da UF no dataset
tab_uf['CD_GEOCUF'] = tab_uf['sigla_uf']\
  .replace(
      ['RO','AC','AM','RR','PA','AP','TO','MA','PI','CE','RN','PB','PE','AL','SE','BA','MG','ES','RJ','SP','PR','SC','RS','MS','MT','GO','DF'],
      ['11','12','13','14','15','16','17','21','22','23','24','25','26','27','28','29','31','32','33','35','41','42','43','50','51','52','53']
  )

# Espiando a tabela
tab_uf.head(5)
# Out:
#   sigla_uf  numero_obitos CD_GEOCUF
# 0       RR             24        14
# 1       AP             25        16
# 2       AC             34        12
# 3       TO             70        17
# 4       RO             93        11

# %%
# Levando os dados para dentro do objeto geoespacial
geo_uf = geo_uf.merge(tab_uf, on='CD_GEOCUF')

#Espiando resultado
geo_uf.head()
# Out:
#   NM_ESTADO NM_REGIAO CD_GEOCUF  \
# 0      ACRE     NORTE        12
# 1   ALAGOAS  NORDESTE        27
# 2     AMAPÁ     NORTE        16
# 3  AMAZONAS     NORTE        13
# 4     BAHIA  NORDESTE        29
#
#                                             geometry sigla_uf  numero_obitos
# 0  POLYGON ((-66.81025 -9.81805, -66.62672 -9.898...       AC             34
# 1  POLYGON ((-35.15253 -8.91384, -35.30432 -9.190...       AL            208
# 2  POLYGON ((-50.09391 0.70209, -50.27176 0.68823...       AP             25
# 3  POLYGON ((-63.37209 2.21186, -63.27635 2.15439...       AM            187
# 4  POLYGON ((-38.23759 -9.32979, -38.23654 -9.331...       BA           1064

# %%
# Verificando mínimo e máximo para definir range do mapa
tab_uf.numero_obitos.describe()
# Out:
# count      27.000000
# mean      677.444444
# std       981.468497
# min        24.000000
# 25%       194.500000
# 50%       272.000000
# 75%       801.500000
# max      4706.000000
# Name: numero_obitos, dtype: float64

# %% [markdown]
# ###### **3. Elaboração do Mapa**

# %%
# Importando as bibliotecas necessarias
import plotly.express as px

# %%
# Criando o mapa
mapa_uf = px.choropleth_mapbox(
    data_frame = tab_uf, 
    geojson = geo_uf, 
    locations='CD_GEOCUF', 
    featureidkey='properties.CD_GEOCUF',
    color='numero_obitos',
    color_continuous_scale= 'RdPu', # escolha paletas de cores https://plotly.com/python/colorscales/
    range_color=(0, 4800),
    mapbox_style="open-street-map",
    zoom=2.5, 
    center = {"lat": -17.14, "lon": -57.33},
    opacity=0.7,
    labels={'numero_obitos':'Óbitos', 
            'CD_GEOCUF' : 'Unidades da Federação'
    },
    width = 800,
    height = 600
)

# %%
# Ajustando as margens
mapa_uf.update_layout(margin={"r":0,"t":0,"l":0,"b":0})

# Exibindo o mapa
mapa_uf.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a32b12dd-d906-4fa3-8f57-da962f8f7595" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a32b12dd-d906-4fa3-8f57-da962f8f7595")) {                    Plotly.newPlot(                        "a32b12dd-d906-4fa3-8f57-da962f8f7595",                        [{"coloraxis":"coloraxis","featureidkey":"properties.CD_GEOCUF","geojson":{"type":"FeatureCollection","features":[{"id":"0","type":"Feature","properties":{"CD_GEOCUF":"12","NM_ESTADO":"ACRE","NM_REGIAO":"NORTE","numero_obitos":34,"sigla_uf":"AC"},"geometry":{"type":"Polygon","coordinates":[[[-66.81025311199988,-9.818045875999971],[-66.62671969099989,-9.898101245000014],[-66.9801989329999,-10.19431558399997],[-67.18033256799991,-10.339460113999955],[-67.3105100489999,-10.320922285999924],[-67.43572846299992,-10.446790359999959],[-67.57903554699993,-10.503396510999941],[-67.70493656899994,-10.699231594000015],[-67.86365695299992,-10.64042424799998],[-68.02089945199992,-10.650235292999955],[-68.27856039799994,-10.989313449999983],[-68.48718609799987,-11.050875333999933],[-68.54297139499988,-11.111355478999908],[-68.7161195959999,-11.145561466999943],[-68.84837791799994,-10.991446527999905],[-69.10253429099997,-10.979946979000022],[-69.40511791399997,-10.927407512999988],[-69.73920890699992,-10.963332661999981],[-69.9325406559999,-10.920607248999993],[-70.14184908299993,-11.029534535999975],[-70.31373699899994,-11.06907759199991],[-70.4357171229999,-11.038774791999973],[-70.5300779019999,-10.93481387099995],[-70.62100662199997,-10.999641142999984],[-70.62058643599994,-9.83225097799998],[-70.52679163599996,-9.72259675999998],[-70.59732897699993,-9.609249056999914],[-70.7583249559999,-9.604977214999955],[-70.86885676999995,-9.664338501999993],[-70.99310915199997,-9.816571680000031],[-71.1630090239999,-9.875320926999965],[-71.21084503599997,-9.966390064999931],[-71.37741667399995,-9.999999995999943],[-72.1804527729999,-9.999999996999943],[-72.15098223899999,-9.79892744099995],[-72.27089314999988,-9.744838163999937],[-72.24624912699991,-9.657194004999937],[-72.34045658199993,-9.506795131999969],[-72.71738764699994,-9.411647296999949],[-73.21189721399995,-9.411669451000005],[-72.94015031399992,-9.069015963000005],[-73.20834619299994,-8.680950629999963],[-73.34397366099994,-8.602083962999952],[-73.32773088599991,-8.481526347999925],[-73.53695137499994,-8.345482304000008],[-73.59395073799986,-8.097404417999932],[-73.74650024299996,-7.952557438999964],[-73.6838098849999,-7.776054932999955],[-73.82167274899993,-7.717497207999969],[-73.94236958099994,-7.598569565999981],[-73.91931376099991,-7.46529186599998],[-73.96617351599994,-7.3516088599999705],[-73.71820555499991,-7.328827769999947],[-73.71380920699995,-7.233858615999967],[-73.8015581149999,-7.111824378999977],[-72.58476562199992,-7.552004229999977],[-71.08849539099991,-7.7262661359999605],[-70.05497934899996,-7.8451491469999866],[-69.37995909199995,-8.42152340699991],[-68.64718643199997,-9.04941656599998],[-67.51688199899996,-9.560906660999958],[-67.32581722099998,-9.592381467999967],[-66.81025311199988,-9.818045875999971]]]},"bbox":[-73.96617351599994,-11.145561466999943,-66.62671969099989,-7.111824378999977]},{"id":"1","type":"Feature","properties":{"CD_GEOCUF":"27","NM_ESTADO":"ALAGOAS","NM_REGIAO":"NORDESTE","numero_obitos":208,"sigla_uf":"AL"},"geometry":{"type":"Polygon","coordinates":[[[-35.15252650099993,-8.913837168999962],[-35.30431623399988,-9.190553226999999],[-35.49765416299992,-9.419712087999944],[-35.81282836599993,-9.732212342999947],[-36.05913054199989,-10.085567733999913],[-36.26935147999992,-10.271283386999897],[-36.393876845999884,-10.500343567999938],[-36.56590148199994,-10.329520637000012],[-36.81431188599999,-10.2188537779998 ...

# %% [markdown]
# ## **Considerações Finais**

# %% [markdown]
# - https://plotly.com/
# - https://matplotlib.org/
# - https://bokeh.org/
# - https://seaborn.pydata.org/
# - https://altair-viz.github.io/
# - https://pandas.pydata.org/docs/user_guide/visualization.html
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html
# - https://github.com/python-visualization/folium
